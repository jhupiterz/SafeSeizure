# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import librosa
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy.fft import fftshift
import os

# %%
path = '/Users/nicolasoederlin/code/jhupiterz/SafeSeizure/SafeSeizure/data/Patient_1_csv/interictal_segment_1.csv'
data = pd.read_csv(path)

# %%
#f, t, Zxx = signal.stft(data.iloc[0],fs=50, nperseg=256)
#plt.figure(figsize=(20,10))
#plt.pcolormesh(t, f, np.abs(Zxx))
#plt.show()

# %%
for i in range (0,15):
    f, t, Zxx = signal.stft(data.iloc[0], fs=50, nperseg=256)
    Zxx_crop = Zxx[:30,]
    f_crop = f[:30]
    plt.pcolormesh(t, f_crop, np.abs(Zxx_crop))
    plt.savefig(f'/Users/nicolasoederlin/code/jhupiterz/SafeSeizure/SafeSeizure/data/img{i}.png')
# Out:
# <ipython-input-214-0ec3ba3f1edb>:5: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(t, f_crop, np.abs(Zxx_crop))

# %%
folder_patient1 = os.listdir('/Users/nicolasoederlin/code/jhupiterz/SafeSeizure/SafeSeizure/data/Patient_1_csv')
folder_patient2 = os.listdir('/Users/nicolasoederlin/code/jhupiterz/SafeSeizure/SafeSeizure/data/Patient_2_csv')

# %%
# !pwd
# Out:
# /Users/nicolasoederlin/code/jhupiterz/SafeSeizure/notebooks

# %%
folder_patient1
# Out:
# ['test_segment_15.csv',
#  'test_segment_29.csv',
#  'interictal_segment_50.csv',
#  'interictal_segment_44.csv',
#  'test_segment_119.csv',
#  'test_segment_125.csv',
#  'test_segment_131.csv',
#  'test_segment_130.csv',
#  'test_segment_124.csv',
#  'test_segment_118.csv',
#  'interictal_segment_45.csv',
#  'test_segment_28.csv',
#  'test_segment_14.csv',
#  'test_segment_16.csv',
#  'interictal_segment_47.csv',
#  'test_segment_132.csv',
#  'test_segment_126.csv',
#  'test_segment_127.csv',
#  'test_segment_133.csv',
#  'interictal_segment_46.csv',
#  'test_segment_17.csv',
#  'test_segment_13.csv',
#  'interictal_segment_42.csv',
#  'test_segment_137.csv',
#  'test_segment_123.csv',
#  'test_segment_122.csv',
#  'test_segment_136.csv',
#  'interictal_segment_43.csv',
#  'test_segment_12.csv',
#  'test_segment_38.csv',
#  'test_segment_10.csv',
#  'interictal_segment_41.csv',
#  'test_segment_120.csv',
#  'test_segment_134.csv',
#  'test_segment_108.csv',
# ...

# %%
for f in folder_patient1:
    data = pd.read_csv(f'../SafeSeizure/data/Patient_1_csv/{f}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-228-f3318990f671> in <module>
#       1 for f in folder_patient1:
# ----> 2     data = pd.read_csv(f'../SafeSeizure/data/Patient_1_csv/{f}')
#       3
#
# ...

# %%
# Out:
# ['test_segment_15.csv',
#  'test_segment_29.csv',
#  'interictal_segment_50.csv',
#  'interictal_segment_44.csv',
#  'test_segment_119.csv',
#  'test_segment_125.csv',
#  'test_segment_131.csv',
#  'test_segment_130.csv',
#  'test_segment_124.csv',
#  'test_segment_118.csv',
#  'interictal_segment_45.csv',
#  'test_segment_28.csv',
#  'test_segment_14.csv',
#  'test_segment_16.csv',
#  'interictal_segment_47.csv',
#  'test_segment_132.csv',
#  'test_segment_126.csv',
#  'test_segment_127.csv',
#  'test_segment_133.csv',
#  'interictal_segment_46.csv',
#  'test_segment_17.csv',
#  'test_segment_13.csv',
#  'interictal_segment_42.csv',
#  'test_segment_137.csv',
#  'test_segment_123.csv',
#  'test_segment_122.csv',
#  'test_segment_136.csv',
#  'interictal_segment_43.csv',
#  'test_segment_12.csv',
#  'test_segment_38.csv',
#  'test_segment_10.csv',
#  'interictal_segment_41.csv',
#  'test_segment_120.csv',
#  'test_segment_134.csv',
#  'test_segment_108.csv',
# ...
